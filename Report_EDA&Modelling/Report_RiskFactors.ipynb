# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
riskdf=pd.read_csv(r"C:\Users\NehaS\Desktop\CS418\RISKFACTORSANDACCESSTOCARE.csv")
riskdf=riskdf.replace(-1111.1,np.NaN)
riskdf
# Out:
#       State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                   1                 1          Autauga         Alabama
# 1                   1                 3          Baldwin         Alabama
# 2                   1                 5          Barbour         Alabama
# 3                   1                 7             Bibb         Alabama
# 4                   1                 9           Blount         Alabama
# ...               ...               ...              ...             ...
# 3136               56                37       Sweetwater         Wyoming
# 3137               56                39            Teton         Wyoming
# 3138               56                41            Uinta         Wyoming
# 3139               56                43         Washakie         Wyoming
# 3140               56                45           Weston         Wyoming
#
#      CHSI_State_Abbr  Strata_ID_Number  No_Exercise  CI_Min_No_Exercise  \
# 0                 AL                29         27.8                20.7
# 1                 AL                16         27.2                23.2
# 2                 AL                51          NaN                 NaN
# 3                 AL                42          NaN                 NaN
# 4                 AL                28         33.5                26.3
# ...              ...               ...          ...                 ...
# 3136              WY                77         21.9                19.8
# 3137              WY                78          9.6                 7.3
# 3138              WY                38         23.4                20.5
# 3139              WY                82         23.2                18.8
# 3140              WY                78         31.3                26.1
#
#       CI_Max_No_Exercise  Few_Fruit_Veg  ...  Diabetes  CI_Min_Diabetes  \
# 0                   34.9           78.6  ...      14.2              9.1
# 1                   31.2           76.2  ...       7.2              5.2
# 2                    NaN            NaN  ...       6.6              2.0
# 3                    NaN           86.6  ...      13.1              4.7
# 4                   40.6           74.6  ...       8.4              4.4
# ...                  ...            ...  ...       ...              ...
# 3136                24.1           80.7  ...       5.3              4.2
# 3137                11.9           68.8  ...       2.4              1.4
# 3138                26.3           83.1  ...       4.8              3.4
# 3139                27.6           78.1  ...       9.4              6.6
# 3140                36.6           75.4  ...       5.7              3.4
#
#       CI_Max_Diabetes  Uninsured  Elderly_Medicare  Disabled_Medicare  \
# 0                19.3       5690              4762               1209
# 1                 9.3      19798             22635               3839
# 2                11.3       5126              3288               1092
# 3                21.5       3315              2390                974
# 4                12.4       8131              5019               1300
# ...               ...        ...               ...                ...
# 3136              6.4       5477              3260                572
# 3137              3.4       1846              1393                 82
# 3138              6.2       3007              1431                357
# 3139             12.1       1178              1338                136
# 3140              8.0        867              1072                143
#
#       Prim_Care_Phys_Rate  Dentist_Rate  Community_Health_Center_Ind  HPSA_Ind
# 0                    45.3          22.6                            1         2
# 1                    67.0          30.8                            1         2
# 2                    45.8          24.6                            1         2
# 3                    41.8          18.6                            1         1
# 4                    16.2          10.8                            2         1
# ...                   ...           ...                          ...       ...
# 3136                 50.0          52.7                            2         1
# 3137                147.1          57.8                            2         2
# 3138                 65.2          40.1                            2         1
# 3139                 50.4          50.4                            1         1
# 3140                 45.0          30.0                            2         1
#
# [3141 rows x 31 columns]

# %%
Illinoisdf=riskdf[riskdf['CHSI_State_Name']=='Illinois']
Illinoisdf
# Out:
#      State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 593               17                 1            Adams        Illinois
# 594               17                 3        Alexander        Illinois
# 595               17                 5             Bond        Illinois
# 596               17                 7            Boone        Illinois
# 597               17                 9            Brown        Illinois
# ..               ...               ...              ...             ...
# 690               17               195        Whiteside        Illinois
# 691               17               197             Will        Illinois
# 692               17               199       Williamson        Illinois
# 693               17               201        Winnebago        Illinois
# 694               17               203         Woodford        Illinois
#
#     CHSI_State_Abbr  Strata_ID_Number  No_Exercise  CI_Min_No_Exercise  \
# 593              IL                21         29.0                22.5
# 594              IL                76          NaN                 NaN
# 595              IL                60          NaN                 NaN
# 596              IL                48          NaN                 NaN
# 597              IL                59          NaN                 NaN
# ..              ...               ...          ...                 ...
# 690              IL                18         22.6                15.9
# 691              IL                10         23.9                20.9
# 692              IL                24         25.0                18.1
# 693              IL                10         25.3                21.9
# 694              IL                47         12.8                 6.7
#
#      CI_Max_No_Exercise  Few_Fruit_Veg  ...  Diabetes  CI_Min_Diabetes  \
# 593                35.6           77.5  ...       7.8              4.4
# 594                 NaN            NaN  ...       1.0              0.0
# 595                 NaN            NaN  ...      13.7              4.9
# 596                 NaN            NaN  ...       5.5              0.0
# 597                 NaN            NaN  ...       NaN              NaN
# ..                  ...            ...  ...       ...              ...
# 690                29.3           84.6  ...       8.3              3.9
# 691                26.9           83.1  ...       5.2              3.8
# 692                31.8            NaN  ...       6.9              3.5
# 693                28.6           76.3  ...       9.3              7.2
# 694                18.9            NaN  ...       7.9              3.3
#
#      CI_Max_Diabetes  Uninsured  Elderly_Medicare  Disabled_Medicare  \
# 593             11.3       6113             11231               1438
# 594              3.0       1715              1484                428
# 595             22.4       1604              2479                370
# 596             12.2       5213              4565                605
# 597              NaN        556               838                121
# ..               ...        ...               ...                ...
# 690             12.6       6934              9920               1524
# 691              6.7      57127             43482               7035
# 692             10.3       7691              9458               1768
# 693             11.5      32344             35312               6282
# 694             12.5       2279              4577                362
#
#      Prim_Care_Phys_Rate  Dentist_Rate  Community_Health_Center_Ind  HPSA_Ind
# 593                 74.6          47.7                            1         2
# 594                 33.6          22.4                            1         2
# 595                 27.7          22.2                            2         2
# 596                 55.5          19.8                            1         2
# 597                 43.9          43.9                            2         1
# ..                   ...           ...                          ...       ...
# 690                 53.5          36.8                            1         2
# 691                 42.9          26.3                            1         2
# 692                 77.0          31.4                            1         2
# 693                 98.4          54.7                            1         2
# 694                 32.0          18.7                            2         1
#
# [102 rows x 31 columns]

# %%
Demodf=pd.read_csv(r"C:/Users/NehaS/Desktop/CS418/DEMOGRAPHICS.csv")
Demodf=Demodf[Demodf['CHSI_State_Name']=='Illinois']
Demodf
# Out:
#      State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 593               17                 1            Adams        Illinois
# 594               17                 3        Alexander        Illinois
# 595               17                 5             Bond        Illinois
# 596               17                 7            Boone        Illinois
# 597               17                 9            Brown        Illinois
# ..               ...               ...              ...             ...
# 690               17               195        Whiteside        Illinois
# 691               17               197             Will        Illinois
# 692               17               199       Williamson        Illinois
# 693               17               201        Winnebago        Illinois
# 694               17               203         Woodford        Illinois
#
#     CHSI_State_Abbr  Strata_ID_Number  \
# 593              IL                21
# 594              IL                76
# 595              IL                60
# 596              IL                48
# 597              IL                59
# ..              ...               ...
# 690              IL                18
# 691              IL                10
# 692              IL                24
# 693              IL                10
# 694              IL                47
#
#                             Strata_Determining_Factors  Number_Counties  \
# 593     frontier status, population size, poverty, age               44
# 594  frontier status, population size, poverty, age...               38
# 595  frontier status, population size, poverty, age...               48
# 596  frontier status, population size, poverty, age...               31
# 597  frontier status, population size, poverty, age...               32
# ..                                                 ...              ...
# 690     frontier status, population size, poverty, age               20
# 691     frontier status, population size, poverty, age               36
# 692     frontier status, population size, poverty, age               35
# 693     frontier status, population size, poverty, age               36
# 694  frontier status, population size, poverty, age...               34
#
#      Population_Size  Min_Population_Size  ...  Max_Black  Native_American  \
# 593            67040                53309  ...       14.9              0.2
# 594             8927                 9226  ...       50.9              0.2
# 595            18027                10534  ...       14.2              0.5
# 596            50483                37787  ...        3.1              0.5
# 597             6835                 7073  ...        2.6              0.0
# ..               ...                  ...  ...        ...              ...
# 690            59863                52773  ...        4.9              0.3
# 691           642813               292916  ...       20.0              0.3
# 692            63617                57558  ...       13.7              0.3
# 693           288695               292916  ...       20.0              0.4
# 694            37448                28085  ...        1.6              0.1
#
#      Min_Native_American  Max_Native_American  Asian  Min_Asian  Max_Asian  \
# 593                  0.1                  1.3    0.5        0.3        1.1
# 594                  0.0                  2.0    0.5        0.2        0.7
# 595                  0.1                  1.0    0.4        0.2        0.7
# 596                  0.2                  0.5    0.9        0.4        1.6
# 597                  0.1                  2.2    0.3        0.2        0.9
# ..                   ...                  ...    ...        ...        ...
# 690                  0.1                  0.7    0.5        0.3        2.1
# 691                  0.2                  0.8    3.5        1.3        8.4
# 692                  0.2                  2.3    0.6        0.3        1.5
# 693                  0.2                  0.8    2.1        1.3        8.4
# 694                  0.1                  1.4    0.5        0.2        1.2
#
#      Hispanic  Min_Hispanic  Max_Hispanic
# 593       0.9           0.8           8.5
# 594       1.7           0.9          12.1
# 595       1.6           0.8           4.5
# 596      16.8           1.0          12.6
# 597       4.4           0.6           7.0
# ..        ...           ...           ...
# 690       9.4           1.2           8.1
# 691      12.7           3.0          20.6
# 692       1.6           0.7          15.0
# 693       9.5           3.0          20.6
# 694       1.0           0.9          12.2
#
# [102 rows x 44 columns]

# %%
ILP=Illinoisdf[Illinoisdf['Prim_Care_Phys_Rate'].notnull()]
ILP=ILP.sort_values(by=['Prim_Care_Phys_Rate'],ascending=False)
barWidth = 2.0
bars = ILP['Prim_Care_Phys_Rate']
sns.set(rc={'figure.figsize':(15,10)})
r1=np.arange(len(bars))
smokerplot=sns.barplot(x=ILP['CHSI_County_Name'],y=bars,errcolor='black', palette='icefire')
smokerplot.set(xlabel='County in Illinois',ylabel='Physicians per 100k population')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As expected, the counties with fewer physicians per 100k population appear to have more uninsured individuals in that County, with 2 outliers, Jackson and Cook. Possibly due to lack of medical staff.

# %% [markdown]
# ### Insights and Hypotheses about Personal Lifestyle and Health Issues from the visualizations
# According to the charts, Counties like Jackson and Du Page appear have healthier habits among the population while counties like Jefferson and Morgan lie on the unhealthier side of almost every chart with higher number of individuals indulging in poor habits. Cook, Knox and Madison appear to lie on the middle range. Comparing this with the insights from the Death and Birth rate charts might reveal patterns for cause and effect. Also, the Demographics of these counties can be studied to determine which counties have higher poverty and how this affects their habits.

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Unsupervised learning - K Means Clustering on Illinois data

# %%
# k-means clustering
from sklearn.cluster import KMeans

phys_level=pd.DataFrame(Illinoisdf[['CHSI_County_Name','Prim_Care_Phys_Rate']])
Deaths_df=pd.read_csv(r"C:\Users\NehaS\Desktop\CS418\MEASURESOFBIRTHANDDEATH.csv")
Deaths_IL=Deaths_df[Deaths_df['CHSI_State_Name']=='Illinois']
deaths_perpop=Deaths_IL.merge(Demodf['Population_Size'], how='left', on=phys_level['CHSI_County_Name'])
death_ratio=np.array([x/y*100 for x,y in zip(deaths_perpop['Total_Deaths'],deaths_perpop['Population_Size'])])
phys_level['Death_Ratio']=death_ratio
X=X=phys_level[['Prim_Care_Phys_Rate','Death_Ratio']].to_numpy()
model = KMeans(n_clusters=3, random_state=1)
model.fit(X)
pred = model.predict(X)

plt.scatter(X[:,0], X[:,1], c=model.labels_,cmap='rainbow_r', s=50)
plt.scatter(model.cluster_centers_[:,0] ,model.cluster_centers_[:,1], color='gold', marker='*', s=250, label='Cluster center')
plt.title("Accessibility to Healthcare to Death Ratio Plot", fontsize=20)
plt.xlabel('Physicians per 100k population')
plt.ylabel('Death Ratio')
plt.legend()

phys_level
# Out:
#     CHSI_County_Name  Prim_Care_Phys_Rate  Death_Ratio
# 593            Adams                 74.6     6.255967
# 594        Alexander                 33.6    14.517755
# 595             Bond                 27.7     9.768680
# 596            Boone                 55.5     2.999029
# 597            Brown                 43.9     8.588149
# ..               ...                  ...          ...
# 690        Whiteside                 53.5     5.190184
# 691             Will                 42.9     1.487991
# 692       Williamson                 77.0     5.776758
# 693        Winnebago                 98.4     2.587506
# 694         Woodford                 32.0     4.590365
#
# [102 rows x 3 columns]

# %% [markdown]
# The Phys_Care_Level and Death_Ratio_Level columns are supposed to be inversly proportional according to what we'd generally assume (More healthcare accessibility, lower death rate). But there are still a few outliers like the data for Will and Brown, since other factors also affect death rate apart from availability of physicians.
#
# The same algorithm can be used on other health factors to assess death ratio relationships.

# %% [markdown]
# ### Data Cleaning and EDA

# %% [markdown]
# 1) Data cleaning: explain how you did data cleaning for your file and show it clearly.
# I cleaned my data specific to the Series I was using and did not use dropna on the entire data frame as some values for each different counties may have been available for different columns like Smokers,Diabetes etc. I also converted numbers like total deaths and total uninsured individuals to a ratio or percentage as that would paint a more accurate picture of the data.
#
# 2) Exploratory data analysis: explain what your data looks like (words are fine, but visualizations are often better). Include any interesting issues or preliminary conclusions you have about your data
# Plotting each of the given columns by county was a bit time consuming but looking at all the smoker, exercise, diet data plotted by county gives an estimate of the overall healthier counties in Illinois.
#
# 3) Reflection:
# The hardest parts I've encountered is dealing with missing data as the algorithm I used (k means clustering) performance depends on finding the mean of all values and hence a missing value cannot be replaced by median or mean as it would disrupt the accuracy of the algorithm and ignoring those rows would result in lesser data to feel into the algortihm.
