# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
Deaths_df=pd.read_csv(r"C:\Users\NehaS\Desktop\CS418\MEASURESOFBIRTHANDDEATH.csv")
Deaths_IL=Deaths_df[Deaths_df['CHSI_State_Name']=='Illinois']
Deaths_IL
# Out:
#      State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 593               17                 1            Adams        Illinois
# 594               17                 3        Alexander        Illinois
# 595               17                 5             Bond        Illinois
# 596               17                 7            Boone        Illinois
# 597               17                 9            Brown        Illinois
# ..               ...               ...              ...             ...
# 690               17               195        Whiteside        Illinois
# 691               17               197             Will        Illinois
# 692               17               199       Williamson        Illinois
# 693               17               201        Winnebago        Illinois
# 694               17               203         Woodford        Illinois
#
#     CHSI_State_Abbr  Strata_ID_Number   LBW  LBW_Ind  Min_LBW  Max_LBW  ...  \
# 593              IL                21   6.4        3      5.4      9.0  ...
# 594              IL                76  12.1        4      7.5     12.1  ...
# 595              IL                60   8.3        4      5.6      8.4  ...
# 596              IL                48   6.4        3      5.5      7.6  ...
# 597              IL                59   6.4        4      5.4      7.8  ...
# ..              ...               ...   ...      ...      ...      ...  ...
# 690              IL                18   5.8        3      5.7      7.9  ...
# 691              IL                10   7.3        3      5.9      8.6  ...
# 692              IL                24   6.9        3      5.7      9.3  ...
# 693              IL                10   8.6        4      5.9      8.6  ...
# 694              IL                47   6.4        3      5.0      7.8  ...
#
#      CI_Max_Suicide  Injury  Injury_Ind  Min_Injury  Max_Injury  \
# 593            13.8    22.5         3.0        16.0        29.8
# 594            21.8    24.2         3.0        19.8        35.0
# 595            13.8    17.1         3.0        15.8        31.4
# 596            11.6    20.4         4.0        16.0        25.9
# 597         -1111.1    20.9         3.0        15.6        29.0
# ..              ...     ...         ...         ...         ...
# 690            13.6    19.7         3.0        17.0        24.9
# 691            10.7    16.5         3.0        13.6        25.2
# 692            16.4    20.5         3.0        18.7        32.1
# 693            12.5    24.6         4.0        13.6        25.2
# 694            12.0    14.4         3.0        14.4        30.2
#
#      CI_Min_Injury  CI_Max_Injury  Total_Births  Total_Deaths  MOBD_Time_Span
# 593           18.1           27.6        4087.0        4194.0       1999-2003
# 594           15.6           35.7        1376.0        1296.0       1994-2003
# 595           11.8           24.0        1959.0        1761.0       1994-2003
# 596           14.5           27.8        3117.0        1514.0       1999-2003
# 597           11.6           34.6         580.0         587.0       1994-2003
# ..             ...            ...           ...           ...             ...
# 690           15.2           25.1        3750.0        3107.0       1999-2003
# 691           14.3           18.7       27088.0        9565.0       2001-2003
# 692           15.9           26.0        3628.0        3675.0       1999-2003
# 693           21.2           27.9       11909.0        7470.0       2001-2003
# 694            9.7           20.7        2144.0        1719.0       1999-2003
#
# [102 rows x 141 columns]

# %%
Death_Infant=Deaths_IL[['CHSI_County_Name','LBW','VLBW','Premature','Under_18','Over_40','Unmarried','Late_Care','Infant_Mortality']]
Death_Infant=Death_Infant.replace(-1111.1,np.NaN)

# %% [markdown]
# ### K-Means Clustering and Multinomial Bayes Classifier for Infant Mortality Rate

# %%
Death_Infant=Death_Infant[Death_Infant['Infant_Mortality'].notnull()]

X=np.array(Death_Infant[['Infant_Mortality','LBW','VLBW']])
model = KMeans(n_clusters=3, random_state=1)
model.fit(X)
pred = model.predict(X)
levels=['2','0','1']
pred_val=[levels[x] for x in pred]
print("The 3 means for calculating low, medium and high healthcare areas using clustering are:")
cluster_cent=zip(levels,model.cluster_centers_)
print([x for x in cluster_cent])
Death_Infant['Death_Level']=pred_val
Death_Infant
# Out:
# The 3 means for calculating low, medium and high healthcare areas using clustering are:
# [('2', array([11.5375,  9.075 ,  1.9375])), ('0', array([5.25769231, 6.68653846, 1.15      ])), ('1', array([8.23076923, 7.34358974, 1.36666667]))]
#     CHSI_County_Name   LBW  VLBW  Premature  Under_18  Over_40  Unmarried  \
# 593            Adams   6.4   1.4       10.4       3.2      1.6       34.4
# 594        Alexander  12.1   2.7       16.3      10.1      1.0       58.2
# 595             Bond   8.3   1.2       12.9       4.0      1.1       27.7
# 596            Boone   6.4   1.2       10.8       3.4      2.2       27.9
# 597            Brown   6.4   1.6       10.0       2.8      1.4       26.7
# ..               ...   ...   ...        ...       ...      ...        ...
# 690        Whiteside   5.8   0.9        8.9       4.8      1.6       38.4
# 691             Will   7.3   1.5       12.0       2.0      2.4       20.7
# 692       Williamson   6.9   1.2       13.0       3.7      1.0       32.9
# 693        Winnebago   8.6   1.9       13.5       3.9      2.0       40.7
# 694         Woodford   6.4   1.2       10.9       1.4      2.8       19.0
#
#      Late_Care  Infant_Mortality Death_Level
# 593       15.2               6.6           0
# 594       22.3              13.1           2
# 595       13.9               8.5           1
# 596       18.1               5.5           0
# 597       22.5               1.9           0
# ..         ...               ...         ...
# 690       11.0               5.3           0
# 691        8.7               6.2           0
# 692       11.8               5.5           0
# 693       18.4               8.5           1
# 694        7.1               7.5           1
#
# [99 rows x 10 columns]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X1=Death_Infant[['LBW','VLBW','Premature','Under_18','Over_40','Unmarried','Late_Care']].to_numpy()
y=Death_Infant['Death_Level'].to_numpy()
X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size=0.20,random_state=9)
clf = MultinomialNB()
clf.fit(X1_train,y_train)
inf_pred=clf.predict(X1_test)
print(accuracy_score(y_test,inf_pred))
# Out:
# 0.6

# %% [markdown]
# ### Backward Elimination to improve model accuracy

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1,2,3,4,5,6]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.932
# Model:                            OLS   Adj. R-squared (uncentered):              0.927
# Method:                 Least Squares   F-statistic:                              180.1
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    7.94e-51
# Time:                        13:20:59   Log-Likelihood:                         -204.09
# No. Observations:                  99   AIC:                                      422.2
# Df Residuals:                      92   BIC:                                      440.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3890      0.292      1.333      0.186      -0.191       0.969
# x2             1.6502      0.712      2.319      0.023       0.237       3.064
# x3             0.1451      0.169      0.859      0.393      -0.191       0.481
# x4             0.0325      0.226      0.144      0.886      -0.416       0.481
# x5            -0.0403      0.406     -0.099      0.921      -0.848       0.767
# x6             0.0309      0.039      0.796      0.428      -0.046       0.108
# x7            -0.0510      0.054     -0.943      0.348      -0.159       0.056
# ==============================================================================
# Omnibus:                        7.471   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.291
# Skew:                          -0.522   Prob(JB):                       0.0261
# Kurtosis:                       3.824   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1,2,3,5,6]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.932
# Model:                            OLS   Adj. R-squared (uncentered):              0.928
# Method:                 Least Squares   F-statistic:                              212.4
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    5.23e-52
# Time:                        13:20:59   Log-Likelihood:                         -204.09
# No. Observations:                  99   AIC:                                      420.2
# Df Residuals:                      93   BIC:                                      435.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3871      0.290      1.337      0.185      -0.188       0.962
# x2             1.6415      0.703      2.337      0.022       0.246       3.037
# x3             0.1387      0.155      0.893      0.374      -0.170       0.447
# x4             0.0447      0.188      0.238      0.813      -0.329       0.419
# x5             0.0310      0.039      0.804      0.424      -0.046       0.108
# x6            -0.0521      0.053     -0.986      0.327      -0.157       0.053
# ==============================================================================
# Omnibus:                        7.324   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.126
# Skew:                          -0.514   Prob(JB):                       0.0284
# Kurtosis:                       3.820   Cond. No.                         135.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1,2,5,6]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.932
# Model:                            OLS   Adj. R-squared (uncentered):              0.928
# Method:                 Least Squares   F-statistic:                              257.4
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    3.18e-53
# Time:                        13:20:59   Log-Likelihood:                         -204.12
# No. Observations:                  99   AIC:                                      418.2
# Df Residuals:                      94   BIC:                                      431.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.3924      0.287      1.366      0.175      -0.178       0.963
# x2             1.6581      0.696      2.384      0.019       0.277       3.039
# x3             0.1353      0.154      0.879      0.381      -0.170       0.441
# x4             0.0355      0.034      1.057      0.293      -0.031       0.102
# x5            -0.0507      0.052     -0.971      0.334      -0.154       0.053
# ==============================================================================
# Omnibus:                        6.801   Durbin-Watson:                   1.725
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                6.468
# Skew:                          -0.494   Prob(JB):                       0.0394
# Kurtosis:                       3.768   Cond. No.                         134.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1,5,6]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.931
# Model:                            OLS   Adj. R-squared (uncentered):              0.928
# Method:                 Least Squares   F-statistic:                              322.4
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    2.44e-54
# Time:                        13:20:59   Log-Likelihood:                         -204.53
# No. Observations:                  99   AIC:                                      417.1
# Df Residuals:                      95   BIC:                                      427.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5852      0.185      3.157      0.002       0.217       0.953
# x2             1.6434      0.695      2.366      0.020       0.265       3.022
# x3             0.0382      0.033      1.146      0.255      -0.028       0.104
# x4            -0.0424      0.051     -0.826      0.411      -0.144       0.060
# ==============================================================================
# Omnibus:                        7.966   Durbin-Watson:                   1.762
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                8.019
# Skew:                          -0.531   Prob(JB):                       0.0181
# Kurtosis:                       3.903   Cond. No.                         126.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1,5]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.931
# Model:                            OLS   Adj. R-squared (uncentered):              0.929
# Method:                 Least Squares   F-statistic:                              431.0
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    1.51e-55
# Time:                        13:20:59   Log-Likelihood:                         -204.88
# No. Observations:                  99   AIC:                                      415.8
# Df Residuals:                      96   BIC:                                      423.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5483      0.180      3.053      0.003       0.192       0.905
# x2             1.5728      0.688      2.286      0.024       0.207       2.939
# x3             0.0309      0.032      0.964      0.338      -0.033       0.095
# ==============================================================================
# Omnibus:                        8.213   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):                8.606
# Skew:                          -0.519   Prob(JB):                       0.0135
# Kurtosis:                       4.005   Cond. No.                         116.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
X_opt =X1[:,[0,1]]
OLS_res = sm.OLS(endog=Death_Infant['Infant_Mortality'], exog=X_opt).fit()
print(OLS_res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Infant_Mortality   R-squared (uncentered):                   0.930
# Model:                            OLS   Adj. R-squared (uncentered):              0.929
# Method:                 Least Squares   F-statistic:                              646.5
# Date:                Wed, 22 Apr 2020   Prob (F-statistic):                    8.34e-57
# Time:                        13:20:59   Log-Likelihood:                         -205.36
# No. Observations:                  99   AIC:                                      414.7
# Df Residuals:                      97   BIC:                                      419.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6693      0.128      5.210      0.000       0.414       0.924
# x2             1.6357      0.685      2.389      0.019       0.277       2.995
# ==============================================================================
# Omnibus:                       10.505   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.836
# Skew:                          -0.609   Prob(JB):                      0.00269
# Kurtosis:                       4.177   Cond. No.                         26.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Accuracy score after performing Backward Elimination

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X2=Death_Infant[['LBW','VLBW']].to_numpy()
y2=Death_Infant['Death_Level'].to_numpy()
X2_train, X2_test, y2_train, y2_test = train_test_split(X1, y, test_size=0.10,random_state=9)
clf = MultinomialNB()
clf.fit(X2_train,y2_train)
inf_pred2=clf.predict(X2_test)
print(accuracy_score(y2_test,inf_pred2))
# Out:
# 0.9
